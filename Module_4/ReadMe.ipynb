# %% [markdown]
# # Описание проекта

# %% [markdown]
# Цели

# %% [markdown]
# 1 Подготовить датасет к использованию моделью машинного обучения.
# 2 Найти скрытые взаимосвязи и выделить признаки наиболее коррелирующие с целевым признаком.
# 3 Очистить датасет от ненужной информации.
# 4 Оценить количество пропусков в столбцах и заполнить.
# 5 Выбрать подходяшую модель машинного обучения и подобрать наилудшие мараметры и метрики.
#
# Данные представляют собой информацию о клиентак банка.
#
#
#
# # Этапы работы.
#
# 1. Вначале познакомился с данными оценил размерность, количество числовых и категориальных признаков.
# 2. Оценил количество пропусков. Заполнил пропуски модой. Привел столбец сдатой к типу datetime.
#
# 3. Оценил распределение номинативных признаков с помошью графиков.
# 4. Оценил распределение числовых признаков с помошью таблицы корреляций и графиков.
# 5. Создал ряд признаков на основе имеющихся ручным способом.
# 6. Создал ряд полиномиальных признаков.
# 7. Из категориальных признаков создал Dummy признаки.
# 8. Попробовал работать с выбросами и изменять их предельными и средними значениями.
# 9. Нормировать признаки способом StandartScaler.
# 10. Подобрал гиперпараметры для модели с помощью GridSearchCV и в ручную
# 11. Оценил результаты спомощью метрик и матрицы ошибок.
# 10. Результат залил на Kaggle и GitHub.

# %% [markdown]
# # Выводы.

# %% [markdown]
# ## Удалось получить 2 модели.
#
# 1. Первая модель не выдает большое количество кредитов людям которые на самом деле бы его вернули, но при этом реже выдает кредит дефолтным клиентам. Что хорошо, когда речь идет о больших суммах кредитов. Это в первую очередь связано с несбалансированостью выборки.
#
# 2. Вторая модель более сбалансирована и потому чвще выдает кредиты но при этом и чаше выдает кредиты дефолтным клиентам. Вслучае с первой моделью доля выданных кредитов дефолтным клиентам 0.039, а со второй уже 0.16.
#
# 3. Использовать лучше сразу 2 модели в зависимости от кредита.
#
# 4. Некоторые признаки имеют большое количество выбросов, но обработка выбросов не принесла результатов.
#
# 5. Также было опробована нормализация. Масштабирование standardscaler.
#
# 6. Были созданы признаки ручным способом, Dummy а также полиномиальные признаки. Что немного улучшило модель.
#
#
# ## На что не хватило времени.
#
# 1. Метрика roc_auc у обоих моделей од 0.731 до 0.741, но на валидации Кaggle опускает score на 0.670. Видимо это связано в переобучением модели. Ксожалению воевать с этим времени уже не хватило.
