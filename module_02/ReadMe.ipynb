# %% [markdown]
# # Описание проекта

# %% [markdown]
# # Цели.
#
# ## 1. Подготовить датасет к использованию моделью машинного обучения.
# ## 2. Найти скрытые взаимосвязи и выделить признаци наиболее коррелирующие с целевым признаком.
# ## 3. Очистить датасет от ненужной информации.
# ## 4. Оценить количество пропусков в столбцах удалить их или заполнить.

# %% [markdown]
# ## Данные представляют собой информацию об учащихся и их результаты тестирования.

# %% [markdown]
# # Этапы работы.
#
# ## 1. Вначале познакомился с данными оценил размерность, количество числовых и категориальных признаков.
#
# ## 2. Оценил количество пропусков. В целевом столбце обнаружил нулевые значения которые скорее всего не правдивы. Удалил такие строки. Меньше 10% датасета.
#
# ## 3. Оценил распределение номинативных признаков с помошью графиков и их взаимосвязь с целевым столбцом 'score'. Оставил столбцы показывающие наибольшую корреляцию. Остальные удалил.
#
# ## 4. Оценил распределение числовых признаков с помошью таблицы корреляций, и дополнительно (PairGrid,pairplot). Выделил наиболие коррелирующие. Остальные удалил.
#
# ## 5. Заполнил пропущенные значения подальными.

# %% [markdown]
# # Выводы

# %% [markdown]
# ## 1. В датасете были расмотрены номинативные и числовые признаки.
# ## 2. С помощью графиков были найдены номинативные признаки, которые наиболее корелируют с целевым столбцом 'score'. Остальные удалены.
# ## 3. Числовые и смешаные признаки оценены с помощью таблици корреляций и выделены наиболее коррелирующие. остальные удалены.
# ## 4. Наибольшая взаимосвязь у числовых и смешаных признаков со столбцом 'score' у столбцов 'failures', 'studytime' и 'medu'.
# ## 5. У номинативных столбцы 'mjob', 'mjob', 'address', 'romantic'. Менее значимые 'school', 'sex', 'reason'.

# %% [markdown]
# # Саморефлексия

# %% [markdown]
# # 1. Работал самостоятельно.
# # 2. В общем приятно было опробовать свои знания на деле и проверить свои знания.
# # 3. Придеться еще поработать над теорией статистики не получилось применить ее. И еще придеться поработать над графиками.
# # 4. Узнал зачем учил материал перед этим. Это хорошо.
# # 5. Получил первый опыт разведывательного анализа.
# # 6. Думаю, что овладел pandas и построением информативных графиков на начальном уровне эти знания могу применять.
# # 7. Обязательно буду изучать дополнительно материалы самостоятельно. Это необходимо.
